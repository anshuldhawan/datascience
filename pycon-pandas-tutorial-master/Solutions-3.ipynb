# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                title  year
# 0  La kermesse rouge  1947
# 1   Surcos en el mar  1956
# 2    Out of Brooklyn  2015
# 3           Zulu Six  2015
# 4     The Crossing 2  2015

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                                title  year       name   type character   n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself NaN

# %%
# Using groupby(), plot the number of films
# that have been released each decade in the history of cinema.

t = titles
t.groupby(t.year // 10 * 10).size().plot(kind='bar')

# %%
# Use groupby() to plot the number of "Hamlet" films made each decade.

t = titles
t = t[t.title == 'Hamlet']
t.groupby(t.year // 10 * 10).size().plot(kind='bar')

# %%
# How many leading (n=1) roles were available to actors,
# and how many to actresses, in each year of the 1950s?

c = cast
c = c[c.year // 10 == 195]
c = c[c.n == 1]
c.groupby(['year', 'type']).size()
# Out:
# year  type
# 1950  actor      605
#       actress    276
# 1951  actor      635
#       actress    273
# 1952  actor      594
#       actress    284
# 1953  actor      633
#       actress    293
# 1954  actor      631
#       actress    297
# 1955  actor      610
#       actress    267
# 1956  actor      618
#       actress    289
# 1957  actor      709
#       actress    286
# 1958  actor      697
#       actress    276
# 1959  actor      687
#       actress    293
# dtype: int64

# %%
# In the 1950s decade taken as a whole,
# how many total roles were available to actors,
# and how many to actresses, for each "n" number 1 through 5?

c = cast
c = c[c.year // 10 * 10 == 1950]
c = c[c.n < 6]
c.groupby(['n', 'type']).size()
# Out:
# n  type
# 1  actor      6419
#    actress    2834
# 2  actor      4412
#    actress    4425
# 3  actor      5436
#    actress    3039
# 4  actor      5433
#    actress    2762
# 5  actor      5459
#    actress    2461
# dtype: int64

# %%
# Use groupby() to determine how many roles are listed
# for each of the Pink Panther movies.

c = cast
c = c[c.title == 'The Pink Panther']
c = c.sort('n')
c
# Out:
#                     title  year                       name     type  \
# 1312535  The Pink Panther  2006               Steve Martin    actor
# 1509971  The Pink Panther  1963                David Niven    actor
# 3340200  The Pink Panther  2006          Colleen Werthmann  actress
# 3360324  The Pink Panther  2006                 Jadin Wong  actress
#
#                                     character   n
# 1312535                              Clouseau   1
# 1509971                    Sir Charles Lytton   1
# 1865034                Insp. Jacques Clouseau   2
# 1101163                               Dreyfus   2
# 2155951                         George Lytton   3
# 1721813                                Ponton   3
# 2984637                                Nicole   4
# 2439901                       Simone Clouseau   4
# 2524573                        Angela Dunning   5
# 463481                                   Yuri   5
# 2464660                                Cherie   6
# 777479                                 Tucker   6
# 1713104                      Raymond Larocque   7
# 1176681                     Defence Barrister   7
# 1160251                                Saloud   8
# 2811842                                 Xania   8
# 775585                    Deputy Chief Renard   9
# 2045322                                Artoff   9
# 723727                              President  10
# 2082844                          Felix Townes  10
# 183472                      Aristotle Sarajos  11
# 842                                      Bizu  11
# 1831975                        Music Producer  12
# 3338637                           Monica Fawn  12
# 1401420           Pierre Luigi - Photographer  13
# 514614              Justice Minister Clochard  13
# 2787251                       Agent Corbeille  14
# 2762423                        Greek 'cousin'  14
# 2440706                        Princess Dahla  15
# 2068449                          Agent Savard  15
# ...                                       ...  ..
# 1099632                             Policeman NaN
# 1114908                       Pierre Fuquette NaN
# 1294197            Extra in Chinese Press Box NaN
# 1421494                        Overweight Man NaN
# 1421495                               Gambler NaN
# 1437040                      Republican Guard NaN
# 1560466                         Nigel Boswell NaN
# 1560467                             Agent 006 NaN
# 1621898                             Policeman NaN
# 1662850                              Croupier NaN
# 1685061              Sneezing Man on Airplane NaN
# 1715773                             Eurotrash NaN
# 1852297                           Maintenance NaN
# 1878159   Kissing Couple in Airplane Bathroom NaN
# 1879678                                 Simon NaN
# 1964634                           Yves Gluant NaN
# 2148888                    French Townsman #1 NaN
# 2166068                         Hotel Manager NaN
# 2177458                    Chinese Footballer NaN
# 2180009                               Plumber NaN
# 2224283  Man in Line for Bathroom on Airplane NaN
# 2259606                                Inmate NaN
# 2498382                                  Girl NaN
# 2739081             Girl in Airplane Bathroom NaN
# 2884358                              Waitress NaN
# 2933267                  Strolling Pedestrian NaN
# 3057550                      Passenger at JFK NaN
# 3291754                                Escort NaN
# 3340200                                  Jane NaN
# 3360324                                Granny NaN
#
# [109 rows x 6 columns]

# %%
c = c = c.groupby(['year'])[['n']].max()
c

# %%
# List, in order by year, each of the films
# in which Frank Oz has played more than 1 role.

c = cast
c = c[c.name == 'Frank Oz']
g = c.groupby(['year', 'title']).size()
g[g > 1]
# Out:
# year  title
# 1979  The Muppet Movie                            8
# 1981  An American Werewolf in London              2
#       The Great Muppet Caper                      6
# 1982  The Dark Crystal                            2
# 1984  The Muppets Take Manhattan                  7
# 1985  Sesame Street Presents: Follow that Bird    3
# 1992  The Muppet Christmas Carol                  7
# 1996  Muppet Treasure Island                      4
# 1999  Muppets from Space                          4
#       The Adventures of Elmo in Grouchland        3
# dtype: int64

# %%
# List each of the characters that Frank Oz
# has portrayed at least twice.

c = cast
c = c[c.name == 'Frank Oz']
g = c.groupby(['character']).size()
g[g > 1].order()
# Out:
# character
# Grover            2
# Bert              3
# Cookie Monster    3
# Fozzie Bear       4
# Sam the Eagle     5
# Yoda              5
# Animal            6
# Miss Piggy        6
# dtype: int64
